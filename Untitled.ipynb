# %%
from datetime import date
import pandas as pd
import numpy as np
from selenium.webdriver.common.keys import Keys
from selenium import webdriver # driving the actions, links up with the browser
from bs4 import BeautifulSoup
import time
import re
from pick import pick
import progressbar
import os

# %%
yes = ["Yes", "Y", "YES", "y", "yes"]
# change the path
search_webpage = 'https://waterlooworks.uwaterloo.ca/myAccount/co-op/coop-postings.htm'
starting_page = "https://waterlooworks.uwaterloo.ca/myAccount/co-op/coop-postings.htm"
dashboard_url = "http://waterlooworks.uwaterloo.ca/myAccount/co-op/coop-postings.htm"
login_url = 'https://cas.uwaterloo.ca/cas/login?service=https://waterlooworks.uwaterloo.ca/waterloo.htm'
output_name = 'WW_postings.csv'
choice = 'Application Deadlines in the next 10 Days'
potential_html1 = None
potential_html2 = None
potential_html3 = None

PATH =  r'C:\Users\esthe\Documents\Coding\chromedriver_win32\chromedriver.exe'
driver = webdriver.Chrome(PATH)
driver.get(search_webpage)

# %%
df = pd.DataFrame(columns=['ID', 'Job Title', 'Organization', 'Division', 'Openings', 'Internal Status', 'City', 'Level',
                           'Applications', 'App Deadline', 'Work Term Duration', "Job Summary", "Job Responsibilities", "Required Skills", 
                           "Targeted Degrees and Disciplines", "Application Documents Required"])

def main():
    starting_page = "https://waterlooworks.uwaterloo.ca/myAccount/co-op/coop-postings.htm"

    output_name = 'WW_postings.csv'
    
    browser = webdriver.Chrome(PATH)
    browser.get(starting_page) # in original script, this was starting page

    input('Are you ready?')

    
    data = get_job_lists(choice, browser, output_name)

    print("Done!")


def get_job_lists(choice, browser, output_name):
    
    print("Getting job lists ...")

    # Navigate to the job listings page then wait for the javascript to load
    browser.find_element_by_link_text(choice).click()

    input("Are you ready again?")
    
    # Get the HTML of the page and check if this is the last page (next_page_buttons)
    page_html = browser.execute_script("return document.body.innerHTML")
    pattern = r'<a href=".+?" onclick="loadPostingTable(.+?)">\s*»\s*<\/a>'
    next_page_buttons = []
    next_page_buttons = re.findall(pattern, page_html)



    # bar = progressbar.ProgressBar(max_value=self.job_lists_page_count)
    # bar.update(self.gather_current_progress)


    # dots for loading screen
    dots = ""
    counter_page = 0
    # Scrape the tables and save it to output_name as a CSV
    job_posting_importants_order = ['Work Term Duration:', "Job Summary:", "Job Responsibilities:", "Required Skills:", 
                                    "Targeted Degrees and Disciplines:", "Application Documents Required:"]
    with open(output_name, 'w') as f:
        row_count = 0
        job_count = 0
        while (counter_page < 1):
            counter_page += 1
            # loading screen stuff
            os.system('clear')
            print("Working" + dots)
            # update dots
            if (dots == "..."):
                dots = ""
            else:
                dots += "."

            # wait for JavaScript to load then download the page info
            time.sleep(2)
            soup = BeautifulSoup(page_html, "html.parser")
            
            for tr in soup.find_all('tr')[2:]: # iterating throw all rows
            
                
                job_count += 1
                print(job_count)
                try:
                    # all the data that was not in the original script
                    job_posting_importants = {"Work Term Duration:": None, # might need to do some regex filtering
                                             "Job Summary:" : None,
                                             "Job Responsibilities:": None,
                                             "Required Skills:" : None,
                                             "Targeted Degrees and Disciplines:": None,
                                             "Application Documents Required:": None} 


                    tds = tr.find_all('td') # iterating all cells in each row.
                    count = 0
                    job_info_list = []
                    for x in tds[0:-1]: # starting with the 3 buttons


                        if (count == 0): # at 3 buttons
                            link_container = x.find_all('a')[2]

                            onclick_link = link_container['onclick']

                            # clicking the onclick link:
                            browser.execute_script(onclick_link)
                            browser.switch_to.window(browser.window_handles[1])

                            # give the browser 1 seconds for the website to catch up with the code
                            browser.implicitly_wait(2)

                            time.sleep(3)
                            # do stuff, locate the texts of 'job posting importants'

                            #saving the contents of the html of the new page:
                            indiv_html = browser.execute_script("return document.body.innerHTML")
                            indiv_posting = BeautifulSoup(indiv_html, "html.parser")

                            # finding the third 'table' in the page, as the first table is no use to us

                            job_posting_information_table = indiv_posting.find_all('table', {'class': 'table-bordered'})[1]


                            
                            #print(job_posting_information_table)


                            # iterating through all rows in the table
                            for row in job_posting_information_table.find_all('tr'): 
                                cell_list = row.find_all('td')
                                try:
                                    key = cell_list[0].get_text().strip()
                                except:
                                    continue


                                if (key in job_posting_importants):
                                    try:
                                        job_posting_importants[key] = cell_list[1].get_text().strip()
                                    except:
                                        job_posting_importants[key] = ""


                            application_information_table = indiv_posting.find_all('table', {'class': 'table-bordered'})[2]
                            job_posting_importants["Application Documents Required:"] = application_information_table.find_all('td')[3].get_text().strip()

                            browser.close() # close current tab
                            browser.switch_to.window(browser.window_handles[0])

                            #print("lala")
                        if (count >= 2):  
                            #print(x.text)
                            job_info_list.append(str(x.text))

                        count += 1


                        
                    for col in job_posting_importants_order:
                        job_info_list.append(job_posting_importants[col])

                    df.loc[row_count] = job_info_list
                    row_count+=1
                except:
                    continue
                
            # navigate to the next page and get the HTML, next page buttons
            next_page_buttons = re.findall(pattern, page_html)
            browser.find_element_by_link_text("»").click()
            time.sleep(2)
            page_html = browser.execute_script("return document.body.innerHTML")


main()
# Out:
# Are you ready?y
# Getting job lists ...
# Are you ready again?y
# Working
# 1
# 2
# 3
# 4
# 5
# 6

# %%
import pandas as pd
import glob

path = r'./2021' # use your path
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

frame = pd.concat(li, axis=0, ignore_index=True)

# %%
frame = frame[frame['Job Title'].notnull()]

# %%
frame
# Out:
#       Unnamed: 0        ID                                          Job Title  \
# 0            0.0  221073.0  \n\n\n\n\t\t\t\t\t\t\t\t\t\tAnalyst, Corporate...
# 1            1.0  223095.0  \n\n\t\t\t\t\t\t\t\t\t\tNEW\n\t\t\t\t\t\t\t\t\...
# 2            2.0  222703.0  \n\n\t\t\t\t\t\t\t\t\t\tNEW\n\t\t\t\t\t\t\t\t\...
# 3            3.0  221765.0  \n\n\t\t\t\t\t\t\t\t\t\tNEW\n\t\t\t\t\t\t\t\t\...
# 4            4.0  219817.0  \n\n\n\n\t\t\t\t\t\t\t\t\t\tProject / Process ...
# ...          ...       ...                                                ...
# 3817       495.0  223413.0  \n\n\t\t\t\t\t\t\t\t\t\tNEW\n\t\t\t\t\t\t\t\t\...
# 3818       496.0  223489.0  \n\n\t\t\t\t\t\t\t\t\t\tNEW\n\t\t\t\t\t\t\t\t\...
# 3819       497.0  223859.0  \n\n\t\t\t\t\t\t\t\t\t\tNEW\n\t\t\t\t\t\t\t\t\...
# 3820       498.0  220808.0  \n\n\n\n\t\t\t\t\t\t\t\t\t\tPolicy Analyst\n\t...
# 3821       499.0  221721.0  \n\n\t\t\t\t\t\t\t\t\t\tNEW\n\t\t\t\t\t\t\t\t\...
#
#                                Organization                         Division  \
# 0                                123Dentist                Divisional Office
# 1                                 AngelList                Divisional office
# 2        ATS Automation Tooling Systems Inc   ASG Cambridge Systems Division
# 3                          Bank of Montreal            BMO Enterprise Campus
# 4                      BFC Technologies Inc                Divisional Office
# ...                                     ...                              ...
# 3817  Environment and Climate Change Canada  Science and Technology Branch 1
# 3818  Environment and Climate Change Canada  Science and Technology Branch 2
# 3819  Environment and Climate Change Canada  Science and Technology Branch 2
# 3820  Environment and Climate Change Canada         Strategic Policy Branch
# 3821  Environment and Climate Change Canada                   Transportation
#
#       Openings        Internal Status              City  \
# 0          1.0  Open for Applications           Toronto
# 1          1.0  Open for Applications  Remote in Canada
# 2          1.0  Open for Applications         Cambridge
# 3          1.0  Open for Applications           Toronto
# 4          1.0  Open for Applications           Vaughan
# ...        ...                    ...               ...
# 3817       1.0  Open for Applications        Burlington
# 3818       2.0  Open for Applications           Toronto
# 3819       1.0  Open for Applications           Toronto
# 3820       1.0  Open for Applications          Gatineau
# 3821       2.0  Open for Applications              Hull
#
#                              Level  Applications  \
# 0             Intermediate, Senior          78.0
# 1                           Senior          37.0
# 2     Junior, Intermediate, Senior           9.0
# 3             Intermediate, Senior           3.0
# 4             Intermediate, Senior          37.0
# ...                            ...           ...
# 3817          Intermediate, Senior           5.0
# 3818                        Junior          35.0
# 3819                  Intermediate           0.0
# 3820  Junior, Intermediate, Senior           6.0
# 3821          Intermediate, Senior          15.0
#
#                                            App Deadline  \
# 0     \n\t\t\t\t\t\t\t\tSep 21, 2021\n\t\t\t\t\t\t\t...
# 1     \n\t\t\t\t\t\t\t\tSep 21, 2021\n\t\t\t\t\t\t\t...
# 2     \n\t\t\t\t\t\t\t\tSep 21, 2021\n\t\t\t\t\t\t\t...
# 3     \n\t\t\t\t\t\t\t\tSep 21, 2021\n\t\t\t\t\t\t\t...
# 4     \n\t\t\t\t\t\t\t\tSep 21, 2021\n\t\t\t\t\t\t\t...
# ...                                                 ...
# 3817  \n\t\t\t\t\t\t\t\tSep 21, 2021\n\t\t\t\t\t\t\t...
# 3818  \n\t\t\t\t\t\t\t\tSep 21, 2021\n\t\t\t\t\t\t\t...
# 3819  \n\t\t\t\t\t\t\t\tSep 21, 2021\n\t\t\t\t\t\t\t...
# 3820  \n\t\t\t\t\t\t\t\tSep 21, 2021\n\t\t\t\t\t\t\t...
# 3821  \n\t\t\t\t\t\t\t\tSep 21, 2021\n\t\t\t\t\t\t\t...
#
#                           Work Term Duration  \
# 0                          4 month work term
# 1                          4 month work term
# 2                          4 month work term
# 3     8 month consecutive work term required
# 4                          4 month work term
# ...                                      ...
# 3817                       4 month work term
# 3818                       4 month work term
# 3819                       4 month work term
# 3820                       4 month work term
# 3821                       4 month work term
#
#                                             Job Summary  \
# 0     123Dentist is a private-equity backed healthca...
# 1     AngelList Venture is seeking a Software Engine...
# 2     Co-op Term: January 10 - April 22, 2022\n\n\nJ...
# 3     As a co-op/intern student at BMO, you will hav...
# 4     Company Description\n\nSpecialized engineering...
# ...                                                 ...
# 3817  This work will involve data management and pre...
# 3818  At Environment and Climate Change Canada (ECCC...
# 3819  Scientific Data Analyst \n\nWe have a one-term...
# 3820  Work Description for Water Co-op Student\n\nEn...
# 3821  Organization and Group Description: Environmen...
#
#                                    Job Responsibilities  \
# 0     As an Analyst, Corporate Development, you will...
# 1     Help build the world's easiest-to-use financia...
# 2     Responsibilities:\n\nReviewing and understandi...
# 3     Liaises with stakeholders to understand proble...
# 4     Job Description / Duties\n\nThe successful can...
# ...                                                 ...
# 3817  Duties include assisting with data downloading...
# 3818  The Organics Analysis Laboratory (OAL) of Envi...
# 3819  The duties of the position may include the fol...
# 3820  Job Title: Policy Analyst \n\nKey Activities:\...
# 3821  Student Responsibilities could include:\n\nAna...
#
#                                         Required Skills  \
# 0     You must have a strong academic track record, ...
# 1     Experienced at writing clean, scalable code wi...
# 2     Necessary skills and experience:\n\n2nd or 3rd...
# 3     Qualifications: \n\nAs a full-time employee, w...
# 4     Educational Requirements\n\n3rd or 4th year En...
# ...                                                 ...
# 3817  Working knowledge of dealing with large data s...
# 3818  The applicant should have successfully complet...
# 3819  Qualifications: \n\nThe position requires expe...
# 3820  Qualifications\n\nEssential:\n\nExperience and...
# 3821  Language Requirements: Fluency in English and/...
#
#                        Targeted Degrees and Disciplines  \
# 0     Targeted Clusters\n\t\t\t\n\n\t\t\n\t\t\n\t\t\...
# 1     Targeted Clusters\n\t\t\t\n\n\t\t\n\t\t\n\t\t\...
# 2     Targeted Clusters\n\t\t\t\n\n\t\t\n\t\t\n\t\t\...
# 3     Targeted Clusters\n\t\t\t\n\n\t\t\n\t\t\n\t\t\...
# 4     Targeted Clusters\n\t\t\t\n\n\t\t\n\t\t\n\t\t\...
# ...                                                 ...
# 3817  Targeted Clusters\n\t\t\t\n\n\t\t\n\t\t\n\t\t\...
# 3818  Targeted Clusters\n\t\t\t\n\n\t\t\n\t\t\n\t\t\...
# 3819  Targeted Clusters\n\t\t\t\n\n\t\t\n\t\t\n\t\t\...
# 3820  Targeted Clusters\n\t\t\t\n\n\t\t\n\t\t\n\t\t\...
# 3821  Targeted Clusters\n\t\t\t\n\n\t\t\n\t\t\n\t\t\...
#
#                          Application Documents Required
# 0     University of Waterloo Co-op Work History,Résu...
# 1     University of Waterloo Co-op Work History,Résu...
# 2     University of Waterloo Co-op Work History,Cove...
# 3     University of Waterloo Co-op Work History,Résu...
# 4     University of Waterloo Co-op Work History,Résu...
# ...                                                 ...
# 3817  University of Waterloo Co-op Work History,Cove...
# 3818  University of Waterloo Co-op Work History,Résu...
# 3819  University of Waterloo Co-op Work History,Cove...
# 3820        Cover Letter,Résumé,Other - Per Job Posting
# 3821  University of Waterloo Co-op Work History,Résu...
#
# [3739 rows x 17 columns]

# %%
df = frame
df = df.fillna("")

# %%
len(df)
# Out:
# 3739

# %%
def surrounding_space_remover(str):
    return ' '.join(str.split())
    
df_space_remover = np.vectorize(surrounding_space_remover)

# %%
len(df)
# Out:
# 3739

# %%
tic = time.time()

for column in ['Job Title', 'App Deadline', 'Targeted Degrees and Disciplines', "Job Summary", "Job Responsibilities", "Required Skills", "Targeted Degrees and Disciplines"]:
    print(column)
    df[column] = df_space_remover(df[column])
    
toc = time.time()

print(str(1000*(toc-tic)))
# Out:
# Job Title
# App Deadline
# Targeted Degrees and Disciplines
# Job Summary
# Job Responsibilities
# Required Skills
# Targeted Degrees and Disciplines
# 544.731616973877

# %%
def new_removal(str):
    try:
        if (str[0:3] == "NEW"): 
            return str[3:]
    except:
        return str # not enough chars in job title
    return str # if no NEW in job title

df_new_remover = np.vectorize(new_removal)

df['Job Title'] = df_new_remover(df["Job Title"])


def day_extractor(str):
    str = str.replace(",", " ")
    str = [int(s) for s in str.split() if s.isdigit()]
    return str[0]

df_day_extractor = np.vectorize(day_extractor)

df['App Deadline'] = df_day_extractor(df["App Deadline"])

# %%
len(df)
# Out:
# 3739

# %%
def cover_letter_needed(mystr):
    if (type(mystr) is not str): 
        print("OH NO!")
        print(type(mystr))
        print(str)
    return ("Cover Letter" in mystr)

df_cover_letter_needed = np.vectorize(cover_letter_needed)

# %%
df["Application Documents Required"] = df_cover_letter_needed(df["Application Documents Required"])

# %%
df.rename(columns={"Application Documents Required": "Cover Letter Needed"}, inplace=True)

# %%
def work_term_duration(str):
    if (str == '4 month work term'): return 1
    if (str == '8 month consecutive work term required'): return 2
    if (str == '8 month consecutive work term preferred'): return 3
    if (str == '2 work term commitment preferred'): return 4
    if (str == '2 work term commitment required'): return 5
    else: return 6 # in case theres smth weird
    
df_work_term_duration = np.vectorize(work_term_duration)

# %%
df["Work Term Duration"] = df_work_term_duration(df["Work Term Duration"])

# %%
df["3_in_one"] = ""
for i in range(len(df["Work Term Duration"])):
    summary = df["Job Summary"].iloc[i]
    respo = df["Job Responsibilities"].iloc[i]
    skills =  df["Required Skills"].iloc[i]
    df["3_in_one"].iloc[i] = summary + respo + skills
# Out:
# c:\program files\python36\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
df
# Out:
#       Unnamed: 0        ID                                          Job Title  \
# 0            0.0  221073.0                     Analyst, Corporate Development
# 1            1.0  223095.0   Venture | Software Engineering, Fund Infrastr...
# 2            2.0  222703.0             Applications Co-op - Mechanical Design
# 3            3.0  221765.0   Technology Business Analyst, Winter 2022 (Co-...
# 4            4.0  219817.0                      Project / Process Engineering
# ...          ...       ...                                                ...
# 3817       495.0  223413.0                                      GIS Assistant
# 3818       496.0  223489.0                                Chemical Technician
# 3819       497.0  223859.0                            Scientific Data Analyst
# 3820       498.0  220808.0                                     Policy Analyst
# 3821       499.0  221721.0         Junior Policy Advisor / Engineering Intern
#
#                                Organization                         Division  \
# 0                                123Dentist                Divisional Office
# 1                                 AngelList                Divisional office
# 2        ATS Automation Tooling Systems Inc   ASG Cambridge Systems Division
# 3                          Bank of Montreal            BMO Enterprise Campus
# 4                      BFC Technologies Inc                Divisional Office
# ...                                     ...                              ...
# 3817  Environment and Climate Change Canada  Science and Technology Branch 1
# 3818  Environment and Climate Change Canada  Science and Technology Branch 2
# 3819  Environment and Climate Change Canada  Science and Technology Branch 2
# 3820  Environment and Climate Change Canada         Strategic Policy Branch
# 3821  Environment and Climate Change Canada                   Transportation
#
#       Openings        Internal Status              City  \
# 0          1.0  Open for Applications           Toronto
# 1          1.0  Open for Applications  Remote in Canada
# 2          1.0  Open for Applications         Cambridge
# 3          1.0  Open for Applications           Toronto
# 4          1.0  Open for Applications           Vaughan
# ...        ...                    ...               ...
# 3817       1.0  Open for Applications        Burlington
# 3818       2.0  Open for Applications           Toronto
# 3819       1.0  Open for Applications           Toronto
# 3820       1.0  Open for Applications          Gatineau
# 3821       2.0  Open for Applications              Hull
#
#                              Level  Applications  App Deadline  \
# 0             Intermediate, Senior          78.0            21
# 1                           Senior          37.0            21
# 2     Junior, Intermediate, Senior           9.0            21
# 3             Intermediate, Senior           3.0            21
# 4             Intermediate, Senior          37.0            21
# ...                            ...           ...           ...
# 3817          Intermediate, Senior           5.0            21
# 3818                        Junior          35.0            21
# 3819                  Intermediate           0.0            21
# 3820  Junior, Intermediate, Senior           6.0            21
# 3821          Intermediate, Senior          15.0            21
#
#       Work Term Duration                                        Job Summary  \
# 0                      1  123Dentist is a private-equity backed healthca...
# 1                      1  AngelList Venture is seeking a Software Engine...
# 2                      1  Co-op Term: January 10 - April 22, 2022 Join t...
# 3                      2  As a co-op/intern student at BMO, you will hav...
# 4                      1  Company Description Specialized engineering co...
# ...                  ...                                                ...
# 3817                   1  This work will involve data management and pre...
# 3818                   1  At Environment and Climate Change Canada (ECCC...
# 3819                   1  Scientific Data Analyst We have a one-term pos...
# 3820                   1  Work Description for Water Co-op Student Envir...
# 3821                   1  Organization and Group Description: Environmen...
#
#                                    Job Responsibilities  \
# 0     As an Analyst, Corporate Development, you will...
# 1     Help build the world's easiest-to-use financia...
# 2     Responsibilities: Reviewing and understanding ...
# 3     Liaises with stakeholders to understand proble...
# 4     Job Description / Duties The successful candid...
# ...                                                 ...
# 3817  Duties include assisting with data downloading...
# 3818  The Organics Analysis Laboratory (OAL) of Envi...
# 3819  The duties of the position may include the fol...
# 3820  Job Title: Policy Analyst Key Activities: Your...
# 3821  Student Responsibilities could include: Analys...
#
#                                         Required Skills  \
# 0     You must have a strong academic track record, ...
# 1     Experienced at writing clean, scalable code wi...
# 2     Necessary skills and experience: 2nd or 3rd ye...
# 3     Qualifications: As a full-time employee, we wo...
# 4     Educational Requirements 3rd or 4th year Engin...
# ...                                                 ...
# 3817  Working knowledge of dealing with large data s...
# 3818  The applicant should have successfully complet...
# 3819  Qualifications: The position requires experien...
# 3820  Qualifications Essential: Experience and/or kn...
# 3821  Language Requirements: Fluency in English and/...
#
#                        Targeted Degrees and Disciplines  Cover Letter Needed  \
# 0     Targeted Clusters - Theme - Business Administr...                False
# 1     Targeted Clusters - Theme - Computing: Softwar...                False
# 2     Targeted Clusters ENG - Electrical and Compute...                 True
# 3     Targeted Clusters - Theme - Business Administr...                False
# 4     Targeted Clusters - Theme - Project and Proces...                False
# ...                                                 ...                  ...
# 3817  Targeted Clusters ENV - Geography and Environm...                 True
# 3818  Targeted Clusters ENG - Chemical Engineering E...                False
# 3819  Targeted Clusters - Theme - Computing: Informa...                 True
# 3820  Targeted Clusters - Theme - Natural Resource M...                 True
# 3821  Targeted Clusters - Theme - Data Analytics, St...                False
#
#                                                3_in_one
# 0     123Dentist is a private-equity backed healthca...
# 1     AngelList Venture is seeking a Software Engine...
# 2     Co-op Term: January 10 - April 22, 2022 Join t...
# 3     As a co-op/intern student at BMO, you will hav...
# 4     Company Description Specialized engineering co...
# ...                                                 ...
# 3817  This work will involve data management and pre...
# 3818  At Environment and Climate Change Canada (ECCC...
# 3819  Scientific Data Analyst We have a one-term pos...
# 3820  Work Description for Water Co-op Student Envir...
# 3821  Organization and Group Description: Environmen...
#
# [3739 rows x 18 columns]

# %%
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.preprocessing import LabelEncoder
from collections import defaultdict
from nltk.corpus import wordnet as wn
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer, TfidfTransformer
from sklearn import model_selection, naive_bayes, svm
from sklearn.metrics import accuracy_score, f1_score, recall_score
np.random.seed(500)
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Job Title', 'Organization', 'Division', 'Openings',
#        'Internal Status', 'City', 'Level', 'Applications', 'App Deadline',
#        'Work Term Duration', 'Job Summary', 'Job Responsibilities',
#        'Required Skills', 'Targeted Degrees and Disciplines',
#        'Cover Letter Needed', '3_in_one'],
#       dtype='object')

# %%
df = df.reset_index().drop(['index', 'Unnamed: 0'], axis=1)

# %%
# Step - b : Change all the text to lower case. This is required as python interprets 'dog' and 'DOG' differently
df["3_in_one"] = [entry.lower() for entry in df["3_in_one"]]
# Step - c : Tokenization : In this each entry in the corpus will be broken into set of words
df["3_in_one"]= [word_tokenize(entry) for entry in df["3_in_one"]]
# Step - d : Remove Stop words, Non-Numeric and perfom Word Stemming/Lemmenting.
# WordNetLemmatizer requires Pos tags to understand if the word is noun or verb or adjective etc. By default it is set to Noun
tag_map = defaultdict(lambda : wn.NOUN)
tag_map['J'] = wn.ADJ
tag_map['V'] = wn.VERB
tag_map['R'] = wn.ADV
for index,entry in enumerate(df["3_in_one"]):
    # Declaring Empty List to store the words that follow the rules for this step
    Final_words = []
    # Initializing WordNetLemmatizer()
    word_Lemmatized = WordNetLemmatizer()
    # pos_tag function below will provide the 'tag' i.e if the word is Noun(N) or Verb(V) or something else.
    for word, tag in pos_tag(entry):
        # Below condition is to check for Stop words and consider only alphabets
        if word not in stopwords.words('english') and word.isalpha():
            word_Final = word_Lemmatized.lemmatize(word,tag_map[tag[0]])
            Final_words.append(word_Final)
    # The final processed set of words for each iteration will be stored in 'text_final'
    df.loc[index,'text_final'] = str(Final_words)

# %%
df = df[df['ID'].notnull()]

# %%
import pickle

# %%
pickleFile = open("svm.pk", 'rb')
SVM = pickle.load(pickleFile)

# %%
df
# Out:
#             ID                                          Job Title  \
# 0     221073.0                     Analyst, Corporate Development
# 1     223095.0   Venture | Software Engineering, Fund Infrastr...
# 2     222703.0             Applications Co-op - Mechanical Design
# 3     221765.0   Technology Business Analyst, Winter 2022 (Co-...
# 4     219817.0                      Project / Process Engineering
# ...        ...                                                ...
# 3734  223413.0                                      GIS Assistant
# 3735  223489.0                                Chemical Technician
# 3736  223859.0                            Scientific Data Analyst
# 3737  220808.0                                     Policy Analyst
# 3738  221721.0         Junior Policy Advisor / Engineering Intern
#
#                                Organization                         Division  \
# 0                                123Dentist                Divisional Office
# 1                                 AngelList                Divisional office
# 2        ATS Automation Tooling Systems Inc   ASG Cambridge Systems Division
# 3                          Bank of Montreal            BMO Enterprise Campus
# 4                      BFC Technologies Inc                Divisional Office
# ...                                     ...                              ...
# 3734  Environment and Climate Change Canada  Science and Technology Branch 1
# 3735  Environment and Climate Change Canada  Science and Technology Branch 2
# 3736  Environment and Climate Change Canada  Science and Technology Branch 2
# 3737  Environment and Climate Change Canada         Strategic Policy Branch
# 3738  Environment and Climate Change Canada                   Transportation
#
#       Openings        Internal Status              City  \
# 0          1.0  Open for Applications           Toronto
# 1          1.0  Open for Applications  Remote in Canada
# 2          1.0  Open for Applications         Cambridge
# 3          1.0  Open for Applications           Toronto
# 4          1.0  Open for Applications           Vaughan
# ...        ...                    ...               ...
# 3734       1.0  Open for Applications        Burlington
# 3735       2.0  Open for Applications           Toronto
# 3736       1.0  Open for Applications           Toronto
# 3737       1.0  Open for Applications          Gatineau
# 3738       2.0  Open for Applications              Hull
#
#                              Level  Applications  App Deadline  \
# 0             Intermediate, Senior          78.0            21
# 1                           Senior          37.0            21
# 2     Junior, Intermediate, Senior           9.0            21
# 3             Intermediate, Senior           3.0            21
# 4             Intermediate, Senior          37.0            21
# ...                            ...           ...           ...
# 3734          Intermediate, Senior           5.0            21
# 3735                        Junior          35.0            21
# 3736                  Intermediate           0.0            21
# 3737  Junior, Intermediate, Senior           6.0            21
# 3738          Intermediate, Senior          15.0            21
#
#       Work Term Duration                                        Job Summary  \
# 0                      1  123Dentist is a private-equity backed healthca...
# 1                      1  AngelList Venture is seeking a Software Engine...
# 2                      1  Co-op Term: January 10 - April 22, 2022 Join t...
# 3                      2  As a co-op/intern student at BMO, you will hav...
# 4                      1  Company Description Specialized engineering co...
# ...                  ...                                                ...
# 3734                   1  This work will involve data management and pre...
# 3735                   1  At Environment and Climate Change Canada (ECCC...
# 3736                   1  Scientific Data Analyst We have a one-term pos...
# 3737                   1  Work Description for Water Co-op Student Envir...
# 3738                   1  Organization and Group Description: Environmen...
#
#                                    Job Responsibilities  \
# 0     As an Analyst, Corporate Development, you will...
# 1     Help build the world's easiest-to-use financia...
# 2     Responsibilities: Reviewing and understanding ...
# 3     Liaises with stakeholders to understand proble...
# 4     Job Description / Duties The successful candid...
# ...                                                 ...
# 3734  Duties include assisting with data downloading...
# 3735  The Organics Analysis Laboratory (OAL) of Envi...
# 3736  The duties of the position may include the fol...
# 3737  Job Title: Policy Analyst Key Activities: Your...
# 3738  Student Responsibilities could include: Analys...
#
#                                         Required Skills  \
# 0     You must have a strong academic track record, ...
# 1     Experienced at writing clean, scalable code wi...
# 2     Necessary skills and experience: 2nd or 3rd ye...
# 3     Qualifications: As a full-time employee, we wo...
# 4     Educational Requirements 3rd or 4th year Engin...
# ...                                                 ...
# 3734  Working knowledge of dealing with large data s...
# 3735  The applicant should have successfully complet...
# 3736  Qualifications: The position requires experien...
# 3737  Qualifications Essential: Experience and/or kn...
# 3738  Language Requirements: Fluency in English and/...
#
#                        Targeted Degrees and Disciplines  Cover Letter Needed  \
# 0     Targeted Clusters - Theme - Business Administr...                False
# 1     Targeted Clusters - Theme - Computing: Softwar...                False
# 2     Targeted Clusters ENG - Electrical and Compute...                 True
# 3     Targeted Clusters - Theme - Business Administr...                False
# 4     Targeted Clusters - Theme - Project and Proces...                False
# ...                                                 ...                  ...
# 3734  Targeted Clusters ENV - Geography and Environm...                 True
# 3735  Targeted Clusters ENG - Chemical Engineering E...                False
# 3736  Targeted Clusters - Theme - Computing: Informa...                 True
# 3737  Targeted Clusters - Theme - Natural Resource M...                 True
# 3738  Targeted Clusters - Theme - Data Analytics, St...                False
#
#                                                3_in_one  \
# 0     [123dentist, is, a, private-equity, backed, he...
# 1     [angellist, venture, is, seeking, a, software,...
# 2     [co-op, term, :, january, 10, -, april, 22, ,,...
# 3     [as, a, co-op/intern, student, at, bmo, ,, you...
# 4     [company, description, specialized, engineerin...
# ...                                                 ...
# 3734  [this, work, will, involve, data, management, ...
# 3735  [at, environment, and, climate, change, canada...
# 3736  [scientific, data, analyst, we, have, a, one-t...
# 3737  [work, description, for, water, co-op, student...
# 3738  [organization, and, group, description, :, env...
#
#                                              text_final
# 0     ['back', 'healthcare', 'company', 'toronto', '...
# 1     ['angellist', 'venture', 'seek', 'software', '...
# 2     ['term', 'january', 'april', 'join', 'win', 't...
# 3     ['student', 'bmo', 'opportunity', 'hear', 'kee...
# 4     ['company', 'description', 'specialize', 'engi...
# ...                                                 ...
# 3734  ['work', 'involve', 'data', 'management', 'pre...
# 3735  ['environment', 'climate', 'change', 'canada',...
# 3736  ['scientific', 'data', 'analyst', 'position', ...
# 3737  ['work', 'description', 'water', 'student', 'e...
# 3738  ['organization', 'group', 'description', 'envi...
#
# [3739 rows x 18 columns]

# %%
df['text_final']
# Out:
# 0       ['back', 'healthcare', 'company', 'toronto', '...
# 1       ['angellist', 'venture', 'seek', 'software', '...
# 2       ['term', 'january', 'april', 'join', 'win', 't...
# 3       ['student', 'bmo', 'opportunity', 'hear', 'kee...
# 4       ['company', 'description', 'specialize', 'engi...
#                               ...
# 3817                                                  NaN
# 3818                                                  NaN
# 3819                                                  NaN
# 3820                                                  NaN
# 3821                                                  NaN
# Name: text_final, Length: 3739, dtype: object

# %%
Train_X_Tfidf = test.transform(df['text_final'])

# %%
(0.2, 'poly', 2, 'auto', 10, 1)
# Out:
# (0.2, 'poly', 2, 'auto', 10, 1)

# %%
(1, 'poly', 3, 'scale', 1, 0)

# %%
(8, 'poly', 2, 'scale', 0, 0)

# %%
predictions_SVM = SVM.predict(Train_X_Tfidf)

# %%
predictions_SVM
# Out:
# array([False, False, False, ..., False,  True, False])

# %%
Train_X_Tfidf
# Out:
# <3739x14096 sparse matrix of type '<class 'numpy.float64'>'
# 	with 585289 stored elements in Compressed Sparse Row format>

# %%
df['yay'] = predictions_SVM

# %%
df[df['yay'] == True].to_csv('yayyyy.csv')
